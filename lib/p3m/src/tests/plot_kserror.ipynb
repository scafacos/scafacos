# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = loadtxt('Q_adi_32.dat', skiprows=1)
alpha = data[:,2]
Q32 = data[:,3]
data = loadtxt('Q_adi_8.dat', skiprows=1)
Q8= data[:,3]
data = loadtxt('Q_adi_64.dat', skiprows=1)
Q64 = data[:,3]

loglog(alpha, Q8, 'o-', label="8")
loglog(alpha, Q32, 'o-', label="32")
loglog(alpha, Q64, 'o-', label="64")
#loglog(alpha/2.0, Q64*sqrt(2.), 'o-', label="16est2")
#loglog(alpha, Q32, 'o-', label="32")
legend(loc="upper left")
